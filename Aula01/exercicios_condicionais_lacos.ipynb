# %% [markdown]
# # 📝 Exercícios — Condicionais e Laços em Python
# ---
# **Instruções:**
# - Resolva cada exercício na célula de código abaixo do enunciado
# - Execute cada célula para testar sua resposta ✅
# - Não se preocupe em acertar de primeira — errar faz parte do aprendizado! 🚀

# %% [markdown]
# ## 🔀 Bloco 1 — `if`, `elif`, `else`

# %% [markdown]
# **Exercício 1**
# Crie uma variável `velocidade` com um valor numérico.
# - Se a velocidade for maior que 120, exiba `"Você está acima da velocidade! 🚨"`
# - Senão, exiba `"Velocidade dentro do limite. ✅"`

# %%
# Sua resposta:

# %% [markdown]
# **Exercício 2**
# Crie uma variável `hora` com um valor de 0 a 23.
# Exiba a saudação correta:
# - 0 a 11 → `"Bom dia! 🌅"`
# - 12 a 17 → `"Boa tarde! ☀️"`
# - 18 a 23 → `"Boa noite! 🌙"`

# %%
# Sua resposta:

# %% [markdown]
# **Exercício 3**
# Crie duas variáveis numéricas `a` e `b`.
# - Se `a` for maior que `b`, exiba qual é o maior
# - Se forem iguais, exiba `"Os valores são iguais"`
# - Senão, exiba qual é o maior

# %%
# Sua resposta:

# %% [markdown]
# **Exercício 4**
# Crie uma variável `usuario` com um nome e `senha` com um valor.
# - Se o usuário for `"admin"` **e** a senha for `1234`, exiba `"Acesso liberado! 🔓"`
# - Senão, exiba `"Acesso negado! 🔒"`

# %%
# Sua resposta:

# %% [markdown]
# **Exercício 5**
# Crie uma lista `estoque` com alguns produtos.
# Crie uma variável `produto_buscado` com um nome.
# - Se o produto estiver na lista, exiba `"Produto encontrado! ✅"`
# - Senão, exiba `"Produto não encontrado. ❌"`

# %%
# Sua resposta:

# %% [markdown]
# ## 🔁 Bloco 2 — `for`

# %% [markdown]
# **Exercício 6**
# Crie uma lista com 5 nomes de colegas.
# Use um `for` para exibir cada nome com uma saudação.
# Exemplo: `"Olá, Maria!"`

# %%
# Sua resposta:

# %% [markdown]
# **Exercício 7**
# Use um `for` com `range()` para exibir todos os números de 1 a 20.

# %%
# Sua resposta:

# %% [markdown]
# **Exercício 8**
# Use um `for` com `range()` para exibir apenas os **múltiplos de 3** entre 1 e 30.

# %%
# Sua resposta:

# %% [markdown]
# **Exercício 9**
# Dada a lista abaixo, use um `for` para somar todos os valores e exibir o total.
# ```python
# precos = [12.50, 8.00, 35.90, 4.75, 22.00]
# ```

# %%
precos = [12.50, 8.00, 35.90, 4.75, 22.00]

# Sua resposta:

# %% [markdown]
# **Exercício 10**
# Dada a lista abaixo, use um `for` para exibir cada palavra em **maiúsculas**.
# > 💡 Dica: `palavra.upper()`
# ```python
# palavras = ["python", "lista", "laço", "código", "aprender"]
# ```

# %%
palavras = ["python", "lista", "laço", "código", "aprender"]

# Sua resposta:

# %% [markdown]
# **Exercício 11**
# Use `enumerate()` para exibir a posição e o nome de cada item da lista.
# Exemplo: `"1: feijão"`
# ```python
# ingredientes = ["feijão", "arroz", "macarrão", "sal", "azeite"]
# ```

# %%
ingredientes = ["feijão", "arroz", "macarrão", "sal", "azeite"]

# Sua resposta:

# %% [markdown]
# ## 🔄 Bloco 3 — `while`

# %% [markdown]
# **Exercício 12**
# Use um `while` para exibir os números de 1 a 10.

# %%
# Sua resposta:

# %% [markdown]
# **Exercício 13**
# Use um `while` para fazer uma contagem regressiva de 10 até 1, e ao final exiba `"🎉 Feliz Ano Novo!"`

# %%
# Sua resposta:

# %% [markdown]
# **Exercício 14**
# Use um `while` para calcular a soma de todos os números **pares** de 2 a 20 e exibir o resultado.

# %%
# Sua resposta:

# %% [markdown]
# **Exercício 15**
# Dada a lista abaixo, use um `while` para remover e exibir cada item até a lista ficar vazia.
# ```python
# fila = ["Alice", "Bruno", "Carol", "Diego"]
# ```
# Exiba: `"Atendendo: Alice"`, `"Atendendo: Bruno"`, etc.

# %%
fila = ["Alice", "Bruno", "Carol", "Diego"]

# Sua resposta:

# %% [markdown]
# ## 🌟 Bloco 4 — Desafios Mistos

# %% [markdown]
# **Exercício 16** ⭐
# Dada a lista abaixo, use um `for` com `if` para criar **duas novas listas**:
# uma com os números **pares** e outra com os **ímpares**.
# Exiba as duas listas ao final.
# ```python
# numeros = [3, 8, 15, 4, 7, 12, 19, 6, 11, 20]
# ```

# %%
numeros = [3, 8, 15, 4, 7, 12, 19, 6, 11, 20]

# Sua resposta:

# %% [markdown]
# **Exercício 17** ⭐
# Dada a lista de notas abaixo, use um `for` para classificar cada aluno:
# - Nota ≥ 7 → `"Aprovado ✅"`
# - Nota entre 5 e 6.9 → `"Recuperação ⚠️"`
# - Nota < 5 → `"Reprovado ❌"`
# ```python
# notas = [8.0, 4.5, 6.0, 9.5, 5.0, 3.0, 7.0]
# ```

# %%
notas = [8.0, 4.5, 6.0, 9.5, 5.0, 3.0, 7.0]

# Sua resposta:

# %% [markdown]
# **Exercício 18** ⭐
# Use um `for` com `range()` para exibir a **tabuada do 8** (de 1 a 10).
# Formato: `"8 x 1 = 8"`, `"8 x 2 = 16"`, etc.

# %%
# Sua resposta:

# %% [markdown]
# **Exercício 19** ⭐
# Dada a lista abaixo, use um `for` para encontrar e exibir o **maior** e o **menor** valor **sem usar** `max()` ou `min()`.
# ```python
# valores = [34, 12, 78, 5, 56, 90, 23, 47]
# ```

# %%
valores = [34, 12, 78, 5, 56, 90, 23, 47]

# Sua resposta:

# %% [markdown]
# **Exercício 20** ⭐⭐ — Desafio Final
# Dada a lista de produtos abaixo, use um `for` com `if` para:
# - a) Contar quantos produtos custam **mais de R$ 50,00**
# - b) Somar o valor **total** de todos os produtos
# - c) Criar uma lista chamada `caros` com os nomes dos produtos acima de R$ 50,00
# - d) Exibir os três resultados
#
# ```python
# produtos = [
#     {"nome": "Caderno",   "preco": 25.90},
#     {"nome": "Mochila",   "preco": 129.00},
#     {"nome": "Caneta",    "preco": 3.50},
#     {"nome": "Calculadora", "preco": 79.90},
#     {"nome": "Borracha",  "preco": 2.00},
#     {"nome": "Estojo",    "preco": 55.00},
# ]
# ```

# %%
produtos = [
    {"nome": "Caderno",     "preco": 25.90},
    {"nome": "Mochila",     "preco": 129.00},
    {"nome": "Caneta",      "preco": 3.50},
    {"nome": "Calculadora", "preco": 79.90},
    {"nome": "Borracha",    "preco": 2.00},
    {"nome": "Estojo",      "preco": 55.00},
]

# Sua resposta:
